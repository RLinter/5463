# %%
# prompt: draw map of Florida with no other states using geopandas.

# !pip install geopandas
import geopandas as gpd
import matplotlib.pyplot as plt

# Download the shapefile for US states (you might need to adjust the URL if needed)
# !wget https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_state_500k.zip
# !unzip cb_2018_us_state_500k.zip

# Read the shapefile into a GeoDataFrame
states = gpd.read_file("cb_2018_us_state_500k.shp")

# Filter for Florida
florida = states[states['NAME'] == 'Florida']

# Create the plot
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
florida.plot(ax=ax, color='lightblue', edgecolor='black')

# Set title and remove axis
ax.set_title('Florida')
ax.axis('off')

# Show the plot
plt.show()
# Out:
# ...
# --2024-11-26 14:44:37--  https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_state_500k.zip
# Resolving www2.census.gov (www2.census.gov)... 23.5.15.106, 2600:1406:5e00:185::208c, 2600:1406:5e00:1a9::208c
# Connecting to www2.census.gov (www2.census.gov)|23.5.15.106|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘cb_2018_us_state_500k.zip’
#
# cb_2018_us_state_50     [ <=>                ]   3.15M  --.-KB/s    in 0.1s
#
# 2024-11-26 14:44:37 (25.9 MB/s) - ‘cb_2018_us_state_500k.zip’ saved [3304931]
#
# Archive:  cb_2018_us_state_500k.zip
#   inflating: cb_2018_us_state_500k.shp.ea.iso.xml
#   inflating: cb_2018_us_state_500k.shp.iso.xml
#   inflating: cb_2018_us_state_500k.shp
#   inflating: cb_2018_us_state_500k.shx
#   inflating: cb_2018_us_state_500k.dbf
#   inflating: cb_2018_us_state_500k.prj
#  extracting: cb_2018_us_state_500k.cpg

# %%
# prompt: draw map of Florida with no other states using geopandas. Also draw each county borders in the map.

import geopandas as gpd
import matplotlib.pyplot as plt

# Download the shapefile for US counties (you might need to adjust the URL if needed)
# !wget https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_county_500k.zip
# !unzip cb_2018_us_county_500k.zip

# Read the shapefile into a GeoDataFrame
counties = gpd.read_file("cb_2018_us_county_500k.shp")

# Filter for Florida counties
florida_counties = counties[counties['STATEFP'] == '12']

# Create the plot
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# Plot Florida counties
florida_counties.plot(ax=ax, color='lightblue', edgecolor='black', linewidth=0.5)

# Set title and remove axis
ax.set_title('Florida Counties')
ax.axis('off')

# Show the plot
plt.show()
# Out:
# --2024-11-26 14:44:43--  https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_county_500k.zip
# Resolving www2.census.gov (www2.census.gov)... 23.5.15.106, 2600:1406:5e00:185::208c, 2600:1406:5e00:1a9::208c
# Connecting to www2.census.gov (www2.census.gov)|23.5.15.106|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘cb_2018_us_county_500k.zip’
#
# cb_2018_us_county_5     [ <=>                ]  11.00M  57.7MB/s    in 0.2s
#
# 2024-11-26 14:44:43 (57.7 MB/s) - ‘cb_2018_us_county_500k.zip’ saved [11530479]
#
# Archive:  cb_2018_us_county_500k.zip
#   inflating: cb_2018_us_county_500k.shp.ea.iso.xml
#   inflating: cb_2018_us_county_500k.shp.iso.xml
#   inflating: cb_2018_us_county_500k.shp
#   inflating: cb_2018_us_county_500k.shx
#   inflating: cb_2018_us_county_500k.dbf
#   inflating: cb_2018_us_county_500k.prj
#  extracting: cb_2018_us_county_500k.cpg

# %%
florida_county_red = florida_counties[florida_counties['NAME'].isin(['Pinellas', 'Hillsborough', 'Polk', 'Manatee', 'Hardee', 'Highlands', 'Sarasota', 'DeSoto', 'Charlotte', 'Glades', 'Lee', 'Hendry', 'Collier'])]

# %%
florida_county_yellow = florida_counties[florida_counties['NAME'].isin(['Monroe', 'Miami-Dade', 'Broward', 'Palm Beach', 'Martin', 'St. Lucie', 'Okeechobee', 'Indian River', 'Osceola', 'Brevard', 'Orange', 'Lake', 'Seminole', 'Citrus', 'Pasco', 'Hernando', 'Sumter', 'Levy', 'Marion'])]

# %%
florida_county_yellow
# Out:
#      STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID          NAME LSAD  \
# 58        12      009  00295749  0500000US12009  12009       Brevard   06
# 64        12      095  00295750  0500000US12095  12095        Orange   06
# 511       12      086  00295755  0500000US12086  12086    Miami-Dade   06
# 512       12      093  00295760  0500000US12093  12093    Okeechobee   06
# 513       12      097  00295748  0500000US12097  12097       Osceola   06
# 667       12      053  00295751  0500000US12053  12053      Hernando   06
# 738       12      069  00308551  0500000US12069  12069          Lake   06
# 964       12      075  00295724  0500000US12075  12075          Levy   06
# 1267      12      087  00295759  0500000US12087  12087        Monroe   06
# 1269      12      111  00308372  0500000US12111  12111     St. Lucie   06
# 1508      12      119  00295740  0500000US12119  12119        Sumter   06
# 1841      12      099  00295761  0500000US12099  12099    Palm Beach   06
# ...

# %%
# prompt: display full list of florida county names

import geopandas as gpd
import matplotlib.pyplot as plt

# Assuming you've already downloaded and unzipped the county shapefile as shown in the previous code

# Read the shapefile into a GeoDataFrame
counties = gpd.read_file("cb_2018_us_county_500k.shp")

# Filter for Florida counties
florida_counties = counties[counties['STATEFP'] == '12']

# Print the list of Florida county names
print(florida_counties['NAME'].tolist())
# Out:
# ['Brevard', 'Columbia', 'Gadsden', 'Highlands', 'Jefferson', 'Leon', 'Orange', 'Putnam', 'Taylor', 'Volusia', 'Walton', 'Washington', 'Liberty', 'Miami-Dade', 'Okeechobee', 'Osceola', 'Escambia', 'Franklin', 'Gilchrist', 'Hamilton', 'Hernando', 'Lee', 'Calhoun', 'Lake', 'Wakulla', 'Madison', 'Santa Rosa', 'Hillsborough', 'Nassau', 'Levy', 'Gulf', 'Polk', 'Suwannee', 'Dixie', 'Bradford', 'Sarasota', 'Flagler', 'Holmes', 'Monroe', 'St. Johns', 'St. Lucie', 'Duval', 'Sumter', 'Palm Beach', 'Lafayette', 'Clay', 'Hardee', 'Alachua', 'DeSoto', 'Indian River', 'Collier', 'Hendry', 'Bay', 'Jackson', 'Pasco', 'Manatee', 'Broward', 'Charlotte', 'Baker', 'Glades', 'Pinellas', 'Martin', 'Okaloosa', 'Citrus', 'Marion', 'Union', 'Seminole']

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Read the shapefile into a GeoDataFrame
counties = gpd.read_file("cb_2018_us_county_500k.shp")

# Filter for Florida counties
florida_counties = counties[counties['STATEFP'] == '12']

# Create the plot
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# Plot Florida counties
florida_counties.plot(ax=ax, color='green', edgecolor='black', linewidth=0.5)
florida_county_red.plot(ax=ax, color='tomato', edgecolor='black', linewidth=0.5)
florida_county_yellow.plot(ax=ax, color='yellow', edgecolor='black', linewidth=0.5)

# Set title and remove axis
ax.set_title('Florida Counties')
ax.axis('off')

# Show the plot
plt.show()

# %%
# prompt: I want to show what each color in the plot means in the legend

# Assuming you've already downloaded and unzipped the county shapefile as shown in the previous code

# Read the shapefile into a GeoDataFrame
counties = gpd.read_file("cb_2018_us_county_500k.shp")

# Filter for Florida counties
florida_counties = counties[counties['STATEFP'] == '12']

# Create the plot
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# Plot Florida counties
florida_counties.plot(ax=ax, color='green', edgecolor='black', linewidth=0.5)
florida_county_red.plot(ax=ax, color='tomato', edgecolor='black', linewidth=0.5)
florida_county_yellow.plot(ax=ax, color='yellow', edgecolor='black', linewidth=0.5)

# Create custom legend
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor='tomato', edgecolor='black', label='Enhanced Hurricane Risk'),
                   Patch(facecolor='yellow', edgecolor='black', label='At-risk'),
                   Patch(facecolor='green', edgecolor='black', label='Marginal risk')]

ax.legend(handles=legend_elements, loc='lower left') # Adjust location as needed


# Set title and remove axis
ax.set_title('Florida Counties')
ax.axis('off')

# Show the plot
plt.show()
